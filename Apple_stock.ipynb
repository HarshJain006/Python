# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AAPL(80-24) Final.csv')

# %%
df.head(5)
# Out:
#          Date   Price    Open    High     Low     Vol. Change %
# 0  03/27/2024  173.31  170.30  173.58  170.14   59.11M    2.12%
# 1  03/26/2024  169.71  170.01  171.41  169.65   57.22M   -0.67%
# 2  03/25/2024  170.85  170.37  171.94  169.46   54.21M   -0.83%
# 3  03/22/2024  172.28  171.76  173.05  170.06   71.16M    0.53%
# 4  03/21/2024  171.37  177.05  177.49  170.84  106.18M   -4.09%

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
start_date ='12/31/2015'
end_date='12/31/2021'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

# %%
filtered_df.set_index('Date', inplace=True)
monthly_avg = filtered_df['Low'].resample('M').mean().reset_index()

# %%
sorted_df = filtered_df.sort_values(by='Date', ascending=True)
sorted_df
# Out:
#              Price    Open    High     Low     Vol. Change %
# Date
# 2015-12-31   26.32   26.75   26.76   26.20  163.65M   -1.90%
# 2016-01-04   26.34   25.65   26.34   25.50  270.60M    0.08%
# 2016-01-05   25.68   26.44   26.46   25.60  223.16M   -2.51%
# 2016-01-06   25.18   25.14   25.59   24.97  273.83M   -1.95%
# 2016-01-07   24.11   24.67   25.03   24.11  324.38M   -4.25%
# ...            ...     ...     ...     ...      ...      ...
# 2021-12-27  180.33  177.09  180.42  177.07   74.92M    2.30%
# 2021-12-28  179.29  180.16  181.33  178.53   79.14M   -0.58%
# 2021-12-29  179.38  179.33  180.63  178.14   62.35M    0.05%
# 2021-12-30  178.20  179.47  180.57  178.09   59.77M   -0.66%
# 2021-12-31  177.57  178.09  179.23  177.26   64.06M   -0.35%
#
# [1512 rows x 6 columns]

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='Date', y='Low',data=monthly_avg)
plt.title('Apple Stock Monthly Average Price (2010-2020)')
plt.xlabel('Date')
plt.ylabel('Average Close Price')
plt.xticks(rotation=45)
plt.grid()

plt.show()
